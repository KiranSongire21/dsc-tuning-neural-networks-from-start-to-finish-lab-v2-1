# %% [markdown]
# # Tuning and Optimizing Neural Networks - Lab
#
# ## Introduction
#
# Now that you've practiced regularization, initialization, and optimization techniques, its time to synthesize these concepts into a cohesive modeling pipeline.
#
# With this pipeline, you will not only fit an initial model but also attempt to improve it. Your final model selection will pertain to the test metrics across these models. This will more naturally simulate a problem you might be faced with in practice, and the various modeling decisions you are apt to encounter along the way.
#
# Recall that our end objective is to achieve a balance between overfitting and underfitting. You've seen the bias variance trade-off, and the role of regularization in order to reduce overfitting on training data and improving generalization to new cases. Common frameworks for such a procedure include train/validate/test methodology when data is plentiful, and K-folds cross-validation for smaller, more limited datasets. In this lab, you'll perform the latter, as the dataset in question is fairly limited.
#
# ## Objectives
#
# You will be able to:
#
# * Apply normalization as a preprocessing technique
# * Implement a K-folds cross validation modeling pipeline for deep learning models
# * Apply regularization techniques to improve your model's performance

# %% [markdown]
# ## Load the data
#
# First, run the following cell to import all the neccessary libraries and classes you will need in this lab.

# %%
# !pip install scikeras
# Out:
# Requirement already satisfied: scikeras in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from scikeras) (3.5.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from scikeras) (1.5.1)
# Requirement already satisfied: absl-py in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (13.3.5)
# Requirement already satisfied: namex in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from keras>=3.2.0->scikeras) (23.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from optree->keras>=3.2.0->scikeras) (4.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from rich->keras>=3.2.0->scikeras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ksongire\appdata\local\anaconda3\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.0)

# %%
# Necessary libraries and classes
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_predict
from keras import models
from keras import layers
from keras import regularizers
from scikeras.wrappers import KerasRegressor

# %% [markdown]
# In this lab you'll be working with the *The Lending Club* data.
#
# - Import the data available in the file `'loan_final.csv'`
# - Drop rows with missing values in the `'total_pymnt'` column (this is your target column)
# - Print the first five rows of the data
# - Print the dimensions of the data

# %%
# Import the data
data = pd.read_csv("loan_final.csv")
data.head()

# Drop rows with no target value
data = data.dropna(subset=["total_pymnt"])

# Print the first five rows
data.head()
# Out:
#    loan_amnt  funded_amnt_inv        term int_rate  installment grade  \
# 0     5000.0           4975.0   36 months   10.65%       162.87     B
# 1     2500.0           2500.0   60 months   15.27%        59.83     C
# 2     2400.0           2400.0   36 months   15.96%        84.33     C
# 3    10000.0          10000.0   36 months   13.49%       339.31     C
# 4     3000.0           3000.0   60 months   12.69%        67.79     B
#
#   emp_length home_ownership  annual_inc verification_status  loan_status  \
# 0  10+ years           RENT     24000.0            Verified   Fully Paid
# 1   < 1 year           RENT     30000.0     Source Verified  Charged Off
# 2  10+ years           RENT     12252.0        Not Verified   Fully Paid
# 3  10+ years           RENT     49200.0     Source Verified   Fully Paid
# 4     1 year           RENT     80000.0     Source Verified   Fully Paid
#
#           purpose addr_state  total_acc   total_pymnt application_type
# 0     credit_card         AZ        9.0   5863.155187       Individual
# 1             car         GA        4.0   1014.530000       Individual
# 2  small_business         IL       10.0   3005.666844       Individual
# 3           other         CA       37.0  12231.890000       Individual
# 4           other         OR       38.0   4066.908161       Individual

# %%
# Print the dimensions of data 
data.shape
# Out:
# (42535, 16)

# %% [markdown]
# ## Generating a Hold Out Test Set
#
# While we will be using K-fold cross validation to select an optimal model, we still want a final hold out test set that is completely independent of any modeling decisions. As such, pull out a sample of 30% of the total available data. For consistency of results, use random seed 42.

# %%
# Features to build the model
features = ['loan_amnt', 'funded_amnt_inv', 'installment', 'annual_inc', 
            'home_ownership', 'verification_status', 'emp_length']

X = data[features]
y = data[['total_pymnt']]

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Preprocessing (Numerical features)
#
# - Fill all missing values in numeric features with their respective means
# - Standardize all the numeric features
# - Convert the final results into DataFrames

# %%
# Select continuous features
cont_features = ['loan_amnt', 'funded_amnt_inv', 'installment', 'annual_inc']

X_train_cont = X_train.loc[:, cont_features]
X_test_cont = X_test.loc[:, cont_features]

# Instantiate SimpleImputer - fill the missing values with the mean
si = SimpleImputer()
si.set_output(transform="pandas")

# Fit and transform the training data
X_train_imputed = si.fit_transform(X_train_cont)

# Transform test data
X_test_imputed = si.transform(X_test_cont)

# Instantiate StandardScaler
ss_X = StandardScaler()
ss_X.set_output(transform="pandas")

# Fit and transform the training data
X_train_scaled = ss_X.fit_transform(X_train_imputed)

# Transform test data
X_test_scaled = ss_X.transform(X_test_imputed)

# %% [markdown]
# ## Preprocessing (Categorical features)
#
# - Fill all missing values in categorical features with the string `'missing'`
# - One-hot encode all categorical features
# - Convert the final results into DataFrames

# %%
# Select only the categorical features
cat_features = ['home_ownership', 'verification_status', 'emp_length']
X_train_cat = X_train.loc[:, cat_features]
X_test_cat = X_test.loc[:, cat_features]

# Fill missing values with the string 'missing'
X_train_cat = X_train_cat.fillna("missing")
X_test_cat = X_test_cat.fillna("missing")

# OneHotEncode categorical variables
ohe = OneHotEncoder(sparse_output=False)
ohe.set_output(transform="pandas")

# Transform training and test sets
X_train_ohe = ohe.fit_transform(X_train_cat)
X_test_ohe = ohe.transform(X_test_cat)

# Get all categorical feature names
# cat_columns = ohe.get_feature_names_out(input_features=X_train_ohe.columns)

# Fit and transform the training data
X_train_categorical = X_train_ohe

# Transform test data
X_test_categorical = X_test_ohe

X_train_categorical.columns
# Out:
# Index(['home_ownership_MORTGAGE', 'home_ownership_NONE',
#        'home_ownership_OTHER', 'home_ownership_OWN', 'home_ownership_RENT',
#        'verification_status_Not Verified',
#        'verification_status_Source Verified', 'verification_status_Verified',
#        'emp_length_1 year', 'emp_length_10+ years', 'emp_length_2 years',
#        'emp_length_3 years', 'emp_length_4 years', 'emp_length_5 years',
#        'emp_length_6 years', 'emp_length_7 years', 'emp_length_8 years',
#        'emp_length_9 years', 'emp_length_< 1 year', 'emp_length_missing'],
#       dtype='object')

# %% [markdown]
# Run the below cell to combine the numeric and categorical features.

# %%
# Combine continuous and categorical feature DataFrames
X_train_all = pd.concat([X_train_scaled, X_train_categorical], axis=1)
X_test_all = pd.concat([X_test_scaled, X_test_categorical], axis=1)

# Number of input features
n_features = X_train_all.shape[1]

# %% [markdown]
# - Standardize the target DataFrames (`y_train` and `y_test`)

# %%
# Instantiate StandardScaler
ss_y = StandardScaler()
ss_y.set_output(transform="pandas")

# Fit and transform Y (train)
y_train_scaled = ss_y.fit_transform(y_train)

# Transform test Y (test)
y_test_scaled = ss_y.transform(y_test)

# %% [markdown]
# ## Define a K-fold Cross Validation Methodology
#
# Now that your have a complete holdout test set, you will perform k-fold cross-validation using the following steps:
#
# - Create a function that returns a compiled deep learning model
# - Use the wrapper function `KerasRegressor()` that defines how these folds are trained
# - Call the `cross_val_predict()` function to perform k-fold cross-validation
#
# In the cell below, we've defined a baseline model that returns a compiled Keras models.

# %%
# Define a function that returns a compiled Keras model 
def create_baseline_model():
    
    # Initialize model
    model = models.Sequential()

    # First hidden layer
    model.add(layers.Dense(10, activation='relu', input_shape=(n_features,)))

    # Second hidden layer
    model.add(layers.Dense(5, activation='relu'))

    # Output layer
    model.add(layers.Dense(1, activation='linear'))

    # Compile the model
    model.compile(optimizer='SGD', 
                  loss='mse',  
                  metrics=['mse']) 
    
    # Return the compiled model
    return model

# %% [markdown]
# Wrap `create_baseline_model` inside a call to `KerasRegressor()`, and:
#
# - Train for 150 epochs
# - Set the batch size to 256
#
# > NOTE: Refer to the [documentation](https://keras.io/scikit-learn-api/) to learn about `KerasRegressor()`.

# %%
# Wrap the above function for use in cross-validation
keras_wrapper_1 = KerasRegressor(
    create_baseline_model,
    epochs=150,
    batch_size=256
)

# %% [markdown]
# Use `cross_val_predict()` to generate cross-validated predictions with:
# - 5-fold cv
# - scaled input (`X_train_all`) and output (`y_train_scaled`)

# %%
# ⏰ This cell may take several mintes to run
# Generate cross-validated predictions
np.random.seed(123)
cv_baseline_preds = cross_val_predict(keras_wrapper_1, X_train_all, y_train_scaled)
# Out:
# C:\Users\ksongire\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.9475 - mse: 0.9475
# Epoch 2/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6641 - mse: 0.6641
# Epoch 3/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5305 - mse: 0.5305
# Epoch 4/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4698 - mse: 0.4698
# Epoch 5/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4123 - mse: 0.4123
# Epoch 6/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3949 - mse: 0.3949
# Epoch 7/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3647 - mse: 0.3647
# Epoch 8/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3425 - mse: 0.3425
# Epoch 9/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3254 - mse: 0.3254
# Epoch 10/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3086 - mse: 0.3086
# Epoch 11/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2869 - mse: 0.2869
# Epoch 12/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2856 - mse: 0.2856
# Epoch 13/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2841 - mse: 0.2841
# Epoch 14/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2713 - mse: 0.2713
# Epoch 15/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2732 - mse: 0.2732
# Epoch 16/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2634 - mse: 0.2634
# Epoch 17/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2600 - mse: 0.2600
# Epoch 18/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2474 - mse: 0.2474
# Epoch 19/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2477 - mse: 0.2477
# Epoch 20/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2408 - mse: 0.2408
# Epoch 21/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.2395 - mse: 0.2395
# Epoch 22/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 0.2463 - mse: 0.2463
# Epoch 23/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2475 - mse: 0.2475
# Epoch 24/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2386 - mse: 0.2386
# Epoch 25/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2294 - mse: 0.2294
# Epoch 26/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2231 - mse: 0.2231
# Epoch 27/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2293 - mse: 0.2293
# Epoch 28/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 0.2266 - mse: 0.2266
# Epoch 29/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2237 - mse: 0.2237
# Epoch 30/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2336 - mse: 0.2336
# Epoch 31/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2231 - mse: 0.2231
# Epoch 32/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2212 - mse: 0.2212
# Epoch 33/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2240 - mse: 0.2240
# Epoch 34/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2219 - mse: 0.2219
# Epoch 35/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2162 - mse: 0.2162
# Epoch 36/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2170 - mse: 0.2170
# Epoch 37/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2121 - mse: 0.2121
# Epoch 38/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2054 - mse: 0.2054
# Epoch 39/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2184 - mse: 0.2184
# Epoch 40/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2085 - mse: 0.2085
# Epoch 41/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2210 - mse: 0.2210
# Epoch 42/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.2052 - mse: 0.2052
# Epoch 43/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2083 - mse: 0.2083
# Epoch 44/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 0.2078 - mse: 0.2078
# Epoch 45/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2066 - mse: 0.2066
# Epoch 46/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.2065 - mse: 0.2065
# Epoch 47/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2136 - mse: 0.2136
# Epoch 48/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2046 - mse: 0.2046
# Epoch 49/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 0.2125 - mse: 0.2125
# Epoch 50/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.2060 - mse: 0.2060
# Epoch 51/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1955 - mse: 0.1955
# Epoch 52/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2062 - mse: 0.2062
# Epoch 53/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2051 - mse: 0.2051
# Epoch 54/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1985 - mse: 0.1985
# Epoch 55/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2037 - mse: 0.2037
# Epoch 56/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2158 - mse: 0.2158
# Epoch 57/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2080 - mse: 0.2080
# Epoch 58/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2093 - mse: 0.2093
# Epoch 59/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2030 - mse: 0.2030
# Epoch 60/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1997 - mse: 0.1997
# Epoch 61/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2068 - mse: 0.2068
# Epoch 62/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1956 - mse: 0.1956
# Epoch 63/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2032 - mse: 0.2032
# Epoch 64/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2013 - mse: 0.2013
# Epoch 65/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2084 - mse: 0.2084
# Epoch 66/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2026 - mse: 0.2026
# Epoch 67/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1990 - mse: 0.1990
# Epoch 68/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1967 - mse: 0.1967
# Epoch 69/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2022 - mse: 0.2022
# Epoch 70/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2046 - mse: 0.2046
# Epoch 71/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2002 - mse: 0.2002
# Epoch 72/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1982 - mse: 0.1982
# Epoch 73/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2005 - mse: 0.2005
# Epoch 74/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2052 - mse: 0.2052
# Epoch 75/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1980 - mse: 0.1980
# Epoch 76/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2116 - mse: 0.2116
# Epoch 77/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2040 - mse: 0.2040
# Epoch 78/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2018 - mse: 0.2018
# Epoch 79/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2005 - mse: 0.2005
# Epoch 80/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1997 - mse: 0.1997
# Epoch 81/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1984 - mse: 0.1984
# Epoch 82/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2052 - mse: 0.2052
# Epoch 83/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2027 - mse: 0.2027
# Epoch 84/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2104 - mse: 0.2104
# Epoch 85/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1965 - mse: 0.1965
# Epoch 86/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1946 - mse: 0.1946
# Epoch 87/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2037 - mse: 0.2037
# Epoch 88/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1961 - mse: 0.1961
# Epoch 89/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2017 - mse: 0.2017
# Epoch 90/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2018 - mse: 0.2018
# Epoch 91/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2063 - mse: 0.2063
# Epoch 92/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1985 - mse: 0.1985
# Epoch 93/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1939 - mse: 0.1939
# Epoch 94/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1940 - mse: 0.1940
# Epoch 95/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1991 - mse: 0.1991
# Epoch 96/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1960 - mse: 0.1960
# Epoch 97/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1998 - mse: 0.1998
# Epoch 98/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1944 - mse: 0.1944
# Epoch 99/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2033 - mse: 0.2033
# Epoch 100/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1919 - mse: 0.1919
# Epoch 101/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1989 - mse: 0.1989
# Epoch 102/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1999 - mse: 0.1999
# Epoch 103/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1962 - mse: 0.1962
# Epoch 104/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1961 - mse: 0.1961
# Epoch 105/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1987 - mse: 0.1987
# Epoch 106/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2035 - mse: 0.2035
# Epoch 107/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1968 - mse: 0.1968
# Epoch 108/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2000 - mse: 0.2000
# Epoch 109/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2025 - mse: 0.2025
# Epoch 110/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2059 - mse: 0.2059
# Epoch 111/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1925 - mse: 0.1925
# Epoch 112/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1958 - mse: 0.1958
# Epoch 113/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1894 - mse: 0.1894
# Epoch 114/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1969 - mse: 0.1969
# Epoch 115/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1986 - mse: 0.1986
# Epoch 116/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1921 - mse: 0.1921
# Epoch 117/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1987 - mse: 0.1987
# Epoch 118/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1874 - mse: 0.1874
# Epoch 119/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1879 - mse: 0.1879
# Epoch 120/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1961 - mse: 0.1961
# Epoch 121/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2023 - mse: 0.2023
# Epoch 122/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1970 - mse: 0.1970
# Epoch 123/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1910 - mse: 0.1910
# Epoch 124/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1941 - mse: 0.1941
# Epoch 125/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1974 - mse: 0.1974
# Epoch 126/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1943 - mse: 0.1943
# Epoch 127/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1995 - mse: 0.1995
# Epoch 128/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2023 - mse: 0.2023
# Epoch 129/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2040 - mse: 0.2040
# Epoch 130/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1970 - mse: 0.1970
# Epoch 131/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1917 - mse: 0.1917
# Epoch 132/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2004 - mse: 0.2004
# Epoch 133/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1950 - mse: 0.1950
# Epoch 134/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1953 - mse: 0.1953
# Epoch 135/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1945 - mse: 0.1945
# Epoch 136/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2010 - mse: 0.2010
# Epoch 137/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1875 - mse: 0.1875
# Epoch 138/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1923 - mse: 0.1923
# Epoch 139/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1873 - mse: 0.1873
# Epoch 140/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1975 - mse: 0.1975
# Epoch 141/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1963 - mse: 0.1963
# Epoch 142/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1941 - mse: 0.1941
# Epoch 143/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1939 - mse: 0.1939
# Epoch 144/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2023 - mse: 0.2023
# Epoch 145/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1922 - mse: 0.1922
# Epoch 146/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2095 - mse: 0.2095
# Epoch 147/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1939 - mse: 0.1939
# Epoch 148/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1914 - mse: 0.1914
# Epoch 149/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1953 - mse: 0.1953
# Epoch 150/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1956 - mse: 0.1956
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 1/150
# C:\Users\ksongire\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.7866 - mse: 0.7866
# Epoch 2/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2673 - mse: 0.2673
# Epoch 3/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2524 - mse: 0.2524
# Epoch 4/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2360 - mse: 0.2360
# Epoch 5/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2312 - mse: 0.2312
# Epoch 6/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2245 - mse: 0.2245
# Epoch 7/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2235 - mse: 0.2235
# Epoch 8/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2210 - mse: 0.2210
# Epoch 9/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2244 - mse: 0.2244
# Epoch 10/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2207 - mse: 0.2207
# Epoch 11/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2167 - mse: 0.2167
# Epoch 12/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2210 - mse: 0.2210
# Epoch 13/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2225 - mse: 0.2225
# Epoch 14/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2120 - mse: 0.2120
# Epoch 15/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2109 - mse: 0.2109
# Epoch 16/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2161 - mse: 0.2161
# Epoch 17/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2081 - mse: 0.2081
# Epoch 18/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2171 - mse: 0.2171
# Epoch 19/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2147 - mse: 0.2147
# Epoch 20/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2062 - mse: 0.2062
# Epoch 21/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2204 - mse: 0.2204
# Epoch 22/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2174 - mse: 0.2174
# Epoch 23/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2090 - mse: 0.2090
# Epoch 24/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2110 - mse: 0.2110
# Epoch 25/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2156 - mse: 0.2156
# Epoch 26/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2107 - mse: 0.2107
# Epoch 27/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2015 - mse: 0.2015
# Epoch 28/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2102 - mse: 0.2102
# Epoch 29/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2102 - mse: 0.2102
# Epoch 30/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2169 - mse: 0.2169
# Epoch 31/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2055 - mse: 0.2055
# Epoch 32/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2162 - mse: 0.2162
# Epoch 33/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2147 - mse: 0.2147
# Epoch 34/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2104 - mse: 0.2104
# Epoch 35/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1989 - mse: 0.1989
# Epoch 36/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2147 - mse: 0.2147
# Epoch 37/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2109 - mse: 0.2109
# Epoch 38/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2131 - mse: 0.2131
# Epoch 39/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2008 - mse: 0.2008
# Epoch 40/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2064 - mse: 0.2064
# Epoch 41/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2092 - mse: 0.2092
# Epoch 42/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2052 - mse: 0.2052
# Epoch 43/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2106 - mse: 0.2106
# Epoch 44/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2044 - mse: 0.2044
# Epoch 45/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2048 - mse: 0.2048
# Epoch 46/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2043 - mse: 0.2043
# Epoch 47/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2005 - mse: 0.2005
# Epoch 48/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 0.2039 - mse: 0.2039
# Epoch 49/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.2075 - mse: 0.2075
# Epoch 50/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.2002 - mse: 0.2002
# Epoch 51/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.1934 - mse: 0.1934
# Epoch 52/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.2113 - mse: 0.2113
# Epoch 53/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 0.1958 - mse: 0.1958
# Epoch 54/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 0.2021 - mse: 0.2021
# Epoch 55/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 0.2055 - mse: 0.2055
# Epoch 56/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 0.2076 - mse: 0.2076
# Epoch 57/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2073 - mse: 0.2073
# Epoch 58/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2049 - mse: 0.2049
# Epoch 59/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.2020 - mse: 0.2020
# Epoch 60/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.2003 - mse: 0.2003
# Epoch 61/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.2073 - mse: 0.2073
# Epoch 62/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 0.2022 - mse: 0.2022
# Epoch 63/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1997 - mse: 0.1997
# Epoch 64/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2044 - mse: 0.2044
# Epoch 65/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1980 - mse: 0.1980
# Epoch 66/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1963 - mse: 0.1963
# Epoch 67/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2085 - mse: 0.2085
# Epoch 68/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1997 - mse: 0.1997
# Epoch 69/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1983 - mse: 0.1983
# Epoch 70/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2013 - mse: 0.2013
# Epoch 71/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2081 - mse: 0.2081
# Epoch 72/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2040 - mse: 0.2040
# Epoch 73/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2064 - mse: 0.2064
# Epoch 74/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1992 - mse: 0.1992
# Epoch 75/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2025 - mse: 0.2025
# Epoch 76/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2057 - mse: 0.2057
# Epoch 77/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2006 - mse: 0.2006
# Epoch 78/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2083 - mse: 0.2083
# Epoch 79/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2065 - mse: 0.2065
# Epoch 80/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2042 - mse: 0.2042
# Epoch 81/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1998 - mse: 0.1998
# Epoch 82/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2065 - mse: 0.2065
# Epoch 83/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2017 - mse: 0.2017
# Epoch 84/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1935 - mse: 0.1935
# Epoch 85/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2019 - mse: 0.2019
# Epoch 86/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1978 - mse: 0.1978
# Epoch 87/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1965 - mse: 0.1965
# Epoch 88/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2024 - mse: 0.2024
# Epoch 89/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2022 - mse: 0.2022
# Epoch 90/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1938 - mse: 0.1938
# Epoch 91/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2001 - mse: 0.2001
# Epoch 92/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2009 - mse: 0.2009
# Epoch 93/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2066 - mse: 0.2066
# Epoch 94/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1916 - mse: 0.1916
# Epoch 95/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2010 - mse: 0.2010
# Epoch 96/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2067 - mse: 0.2067
# Epoch 97/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2009 - mse: 0.2009
# Epoch 98/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2046 - mse: 0.2046
# Epoch 99/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1984 - mse: 0.1984
# Epoch 100/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2068 - mse: 0.2068
# Epoch 101/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1981 - mse: 0.1981
# Epoch 102/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2074 - mse: 0.2074
# Epoch 103/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1992 - mse: 0.1992
# Epoch 104/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2018 - mse: 0.2018
# Epoch 105/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2041 - mse: 0.2041
# Epoch 106/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1966 - mse: 0.1966
# Epoch 107/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1989 - mse: 0.1989
# Epoch 108/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2054 - mse: 0.2054
# Epoch 109/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1944 - mse: 0.1944
# Epoch 110/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2021 - mse: 0.2021
# Epoch 111/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1979 - mse: 0.1979
# Epoch 112/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1981 - mse: 0.1981
# Epoch 113/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2022 - mse: 0.2022
# Epoch 114/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1963 - mse: 0.1963
# Epoch 115/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2092 - mse: 0.2092
# Epoch 116/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1991 - mse: 0.1991
# Epoch 117/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2012 - mse: 0.2012
# Epoch 118/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1992 - mse: 0.1992
# Epoch 119/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1890 - mse: 0.1890
# Epoch 120/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1980 - mse: 0.1980
# Epoch 121/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1942 - mse: 0.1942
# Epoch 122/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1996 - mse: 0.1996
# Epoch 123/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1922 - mse: 0.1922
# Epoch 124/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2059 - mse: 0.2059
# Epoch 125/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2046 - mse: 0.2046
# Epoch 126/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1895 - mse: 0.1895
# Epoch 127/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2002 - mse: 0.2002
# Epoch 128/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2008 - mse: 0.2008
# Epoch 129/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1910 - mse: 0.1910
# Epoch 130/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1978 - mse: 0.1978
# Epoch 131/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1995 - mse: 0.1995
# Epoch 132/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1977 - mse: 0.1977
# Epoch 133/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2048 - mse: 0.2048
# Epoch 134/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1957 - mse: 0.1957
# Epoch 135/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1992 - mse: 0.1992
# Epoch 136/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2048 - mse: 0.2048
# Epoch 137/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1909 - mse: 0.1909
# Epoch 138/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1922 - mse: 0.1922
# Epoch 139/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1996 - mse: 0.1996
# Epoch 140/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1943 - mse: 0.1943
# Epoch 141/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1990 - mse: 0.1990
# Epoch 142/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1913 - mse: 0.1913
# Epoch 143/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1997 - mse: 0.1997
# Epoch 144/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1960 - mse: 0.1960
# Epoch 145/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1921 - mse: 0.1921
# Epoch 146/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1981 - mse: 0.1981
# Epoch 147/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1881 - mse: 0.1881
# Epoch 148/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1934 - mse: 0.1934
# Epoch 149/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1977 - mse: 0.1977
# Epoch 150/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2007 - mse: 0.2007
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/150
# C:\Users\ksongire\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.8725 - mse: 0.8725
# Epoch 2/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2854 - mse: 0.2854
# Epoch 3/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2587 - mse: 0.2587
# Epoch 4/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2487 - mse: 0.2487
# Epoch 5/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2416 - mse: 0.2416
# Epoch 6/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2405 - mse: 0.2405
# Epoch 7/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2316 - mse: 0.2316
# Epoch 8/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2236 - mse: 0.2236
# Epoch 9/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2179 - mse: 0.2179
# Epoch 10/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2276 - mse: 0.2276
# Epoch 11/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2186 - mse: 0.2186
# Epoch 12/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2167 - mse: 0.2167
# Epoch 13/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2181 - mse: 0.2181
# Epoch 14/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2151 - mse: 0.2151
# Epoch 15/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2071 - mse: 0.2071
# Epoch 16/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2215 - mse: 0.2215
# Epoch 17/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2166 - mse: 0.2166
# Epoch 18/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2133 - mse: 0.2133
# Epoch 19/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2059 - mse: 0.2059
# Epoch 20/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2115 - mse: 0.2115
# Epoch 21/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2172 - mse: 0.2172
# Epoch 22/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2148 - mse: 0.2148
# Epoch 23/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2151 - mse: 0.2151
# Epoch 24/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2060 - mse: 0.2060
# Epoch 25/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2051 - mse: 0.2051
# Epoch 26/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2057 - mse: 0.2057
# Epoch 27/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2065 - mse: 0.2065
# Epoch 28/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2057 - mse: 0.2057
# Epoch 29/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2048 - mse: 0.2048
# Epoch 30/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2113 - mse: 0.2113
# Epoch 31/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.
150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1958 - mse: 0.1958
# Epoch 106/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1811 - mse: 0.1811
# Epoch 107/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1900 - mse: 0.1900
# Epoch 108/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 0.1948 - mse: 0.1948
# Epoch 109/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.1859 - mse: 0.1859
# Epoch 110/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1943 - mse: 0.1943
# Epoch 111/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1924 - mse: 0.1924
# Epoch 112/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1948 - mse: 0.1948
# Epoch 113/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1919 - mse: 0.1919
# Epoch 114/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1960 - mse: 0.1960
# Epoch 115/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1934 - mse: 0.1934
# Epoch 116/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1921 - mse: 0.1921
# Epoch 117/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1910 - mse: 0.1910
# Epoch 118/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1952 - mse: 0.1952
# Epoch 119/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1963 - mse: 0.1963
# Epoch 120/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1852 - mse: 0.1852
# Epoch 121/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1870 - mse: 0.1870
# Epoch 122/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1936 - mse: 0.1936
# Epoch 123/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1948 - mse: 0.1948
# Epoch 124/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1945 - mse: 0.1945
# Epoch 125/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1862 - mse: 0.1862
# Epoch 126/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1873 - mse: 0.1873
# Epoch 127/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1878 - mse: 0.1878
# Epoch 128/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1944 - mse: 0.1944
# Epoch 129/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1947 - mse: 0.1947
# Epoch 130/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1931 - mse: 0.1931
# Epoch 131/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1891 - mse: 0.1891
# Epoch 132/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1937 - mse: 0.1937
# Epoch 133/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1884 - mse: 0.1884
# Epoch 134/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1910 - mse: 0.1910
# Epoch 135/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1876 - mse: 0.1876
# Epoch 136/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1848 - mse: 0.1848
# Epoch 137/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1934 - mse: 0.1934
# Epoch 138/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1881 - mse: 0.1881
# Epoch 139/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1873 - mse: 0.1873
# Epoch 140/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1905 - mse: 0.1905
# Epoch 141/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 0.1922 - mse: 0.1922
# Epoch 142/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1932 - mse: 0.1932
# Epoch 143/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1941 - mse: 0.1941
# Epoch 144/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1840 - mse: 0.1840
# Epoch 145/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1873 - mse: 0.1873
# Epoch 146/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1900 - mse: 0.1900
# Epoch 147/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 0.1889 - mse: 0.1889
# Epoch 148/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1904 - mse: 0.1904
# Epoch 149/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1906 - mse: 0.1906
# Epoch 150/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1945 - mse: 0.1945
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 1/150
# C:\Users\ksongire\AppData\Local\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.8809 - mse: 0.8809
# Epoch 2/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3276 - mse: 0.3276
# Epoch 3/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2585 - mse: 0.2585
# Epoch 4/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2491 - mse: 0.2491
# Epoch 5/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2371 - mse: 0.2371
# Epoch 6/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2344 - mse: 0.2344
# Epoch 7/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2263 - mse: 0.2263
# Epoch 8/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2307 - mse: 0.2307
# Epoch 9/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2307 - mse: 0.2307
# Epoch 10/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2155 - mse: 0.2155
# Epoch 11/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2246 - mse: 0.2246
# Epoch 12/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2217 - mse: 0.2217
# Epoch 13/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2240 - mse: 0.2240
# Epoch 14/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2137 - mse: 0.2137
# Epoch 15/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2238 - mse: 0.2238
# Epoch 16/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2197 - mse: 0.2197
# Epoch 17/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2147 - mse: 0.2147
# Epoch 18/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2062 - mse: 0.2062
# Epoch 19/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2021 - mse: 0.2021
# Epoch 20/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2160 - mse: 0.2160
# Epoch 21/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2168 - mse: 0.2168
# Epoch 22/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2054 - mse: 0.2054
# Epoch 23/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2159 - mse: 0.2159
# Epoch 24/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2084 - mse: 0.2084
# Epoch 25/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2067 - mse: 0.2067
# Epoch 26/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2133 - mse: 0.2133
# Epoch 27/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2082 - mse: 0.2082
# Epoch 28/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2087 - mse: 0.2087
# Epoch 29/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2122 - mse: 0.2122
# Epoch 30/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2113 - mse: 0.2113
# Epoch 31/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2116 - mse: 0.2116
# Epoch 32/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2034 - mse: 0.2034
# Epoch 33/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2095 - mse: 0.2095
# Epoch 34/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.2109 - mse: 0.2109
# Epoch 35/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.2091 - mse: 0.2091
# Epoch 36/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - loss: 0.2046 - mse: 0.2046
# Epoch 37/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 0.2046 - mse: 0.2046
# Epoch 38/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 0.2088 - mse: 0.2088
# Epoch 39/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 0.2077 - mse: 0.2077
# Epoch 40/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 0.2070 - mse: 0.2070
# Epoch 41/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1978 - mse: 0.1978
# Epoch 42/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2015 - mse: 0.2015
# Epoch 43/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2002 - mse: 0.2002
# Epoch 44/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2067 - mse: 0.2067
# Epoch 45/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 0.1941 - mse: 0.1941
# Epoch 46/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2107 - mse: 0.2107
# Epoch 47/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.1999 - mse: 0.1999
# Epoch 48/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1000us/step - loss: 0.1991 - mse: 0.1991
# Epoch 49/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1991 - mse: 0.1991
# Epoch 50/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 0.2057 - mse: 0.2057
# Epoch 51/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2024 - mse: 0.2024
# Epoch 52/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1999 - mse: 0.1999
# Epoch 53/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2098 - mse: 0.2098
# Epoch 54/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1950 - mse: 0.1950
# Epoch 55/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2012 - mse: 0.2012
# Epoch 56/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2013 - mse: 0.2013
# Epoch 57/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2052 - mse: 0.2052
# Epoch 58/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2100 - mse: 0.2100
# Epoch 59/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2083 - mse: 0.2083
# Epoch 60/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 0.1947 - mse: 0.1947
# Epoch 61/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2065 - mse: 0.2065
# Epoch 62/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 0.2019 - mse: 0.2019
# Epoch 63/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2050 - mse: 0.2050
# Epoch 64/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.1967 - mse: 0.1967
# Epoch 65/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2070 - mse: 0.2070
# Epoch 66/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1957 - mse: 0.1957
# Epoch 67/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2028 - mse: 0.2028
# Epoch 68/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1995 - mse: 0.1995
# Epoch 69/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2087 - mse: 0.2087
# Epoch 70/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1962 - mse: 0.1962
# Epoch 71/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2033 - mse: 0.2033
# Epoch 72/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2047 - mse: 0.2047
# Epoch 73/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2083 - mse: 0.2083
# Epoch 74/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2061 - mse: 0.2061
# Epoch 75/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1994 - mse: 0.1994
# Epoch 76/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1970 - mse: 0.1970
# Epoch 77/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.2034 - mse: 0.2034
# Epoch 78/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 0.2032 - mse: 0.2032
# Epoch 79/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 0.2013 - mse: 0.2013
# Epoch 80/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.1965 - mse: 0.1965
# Epoch 81/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.2035 - mse: 0.2035
# Epoch 82/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 0.2017 - mse: 0.2017
# Epoch 83/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.1992 - mse: 0.1992
# Epoch 84/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 0.1958 - mse: 0.1958
# Epoch 85/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1942 - mse: 0.1942
# Epoch 86/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1947 - mse: 0.1947
# Epoch 87/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2011 - mse: 0.2011
# Epoch 88/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1937 - mse: 0.1937
# Epoch 89/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2084 - mse: 0.2084
# Epoch 90/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1921 - mse: 0.1921
# Epoch 91/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1953 - mse: 0.1953
# Epoch 92/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1976 - mse: 0.1976
# Epoch 93/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1948 - mse: 0.1948
# Epoch 94/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 0.1880 - mse: 0.1880
# Epoch 95/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 0.2089 - mse: 0.2089
# Epoch 96/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0
150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2167 - mse: 0.2167
# Epoch 19/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 0.2230 - mse: 0.2230
# Epoch 20/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2163 - mse: 0.2163
# Epoch 21/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2178 - mse: 0.2178
# Epoch 22/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2224 - mse: 0.2224
# Epoch 23/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2147 - mse: 0.2147
# Epoch 24/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2137 - mse: 0.2137
# Epoch 25/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2167 - mse: 0.2167
# Epoch 26/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2242 - mse: 0.2242
# Epoch 27/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2094 - mse: 0.2094
# Epoch 28/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2158 - mse: 0.2158
# Epoch 29/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2166 - mse: 0.2166
# Epoch 30/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2144 - mse: 0.2144
# Epoch 31/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2125 - mse: 0.2125
# Epoch 32/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2179 - mse: 0.2179
# Epoch 33/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2140 - mse: 0.2140
# Epoch 34/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2071 - mse: 0.2071
# Epoch 35/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2056 - mse: 0.2056
# Epoch 36/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2116 - mse: 0.2116
# Epoch 37/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2104 - mse: 0.2104
# Epoch 38/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2067 - mse: 0.2067
# Epoch 39/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2084 - mse: 0.2084
# Epoch 40/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.2039 - mse: 0.2039
# Epoch 41/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2051 - mse: 0.2051
# Epoch 42/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2070 - mse: 0.2070
# Epoch 43/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2043 - mse: 0.2043
# Epoch 44/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1977 - mse: 0.1977
# Epoch 45/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2062 - mse: 0.2062
# Epoch 46/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1989 - mse: 0.1989
# Epoch 47/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2032 - mse: 0.2032
# Epoch 48/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2007 - mse: 0.2007
# Epoch 49/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2074 - mse: 0.2074
# Epoch 50/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2122 - mse: 0.2122
# Epoch 51/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2032 - mse: 0.2032
# Epoch 52/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2020 - mse: 0.2020
# Epoch 53/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2040 - mse: 0.2040
# Epoch 54/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2011 - mse: 0.2011
# Epoch 55/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1980 - mse: 0.1980
# Epoch 56/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2041 - mse: 0.2041
# Epoch 57/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2013 - mse: 0.2013
# Epoch 58/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2012 - mse: 0.2012
# Epoch 59/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2005 - mse: 0.2005
# Epoch 60/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2091 - mse: 0.2091
# Epoch 61/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 0.2012 - mse: 0.2012
# Epoch 62/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2026 - mse: 0.2026
# Epoch 63/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 0.2030 - mse: 0.2030
# Epoch 64/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 0.1958 - mse: 0.1958
# Epoch 65/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 0.2019 - mse: 0.2019
# Epoch 66/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 0.2084 - mse: 0.2084
# Epoch 67/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1977 - mse: 0.1977
# Epoch 68/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 0.1997 - mse: 0.1997
# Epoch 69/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2062 - mse: 0.2062
# Epoch 70/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2016 - mse: 0.2016
# Epoch 71/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2019 - mse: 0.2019
# Epoch 72/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2041 - mse: 0.2041
# Epoch 73/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2055 - mse: 0.2055
# Epoch 74/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1990 - mse: 0.1990
# Epoch 75/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1917 - mse: 0.1917
# Epoch 76/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2048 - mse: 0.2048
# Epoch 77/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2021 - mse: 0.2021
# Epoch 78/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1933 - mse: 0.1933
# Epoch 79/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2032 - mse: 0.2032
# Epoch 80/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1969 - mse: 0.1969
# Epoch 81/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2096 - mse: 0.2096
# Epoch 82/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2032 - mse: 0.2032
# Epoch 83/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2062 - mse: 0.2062
# Epoch 84/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2005 - mse: 0.2005
# Epoch 85/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1916 - mse: 0.1916
# Epoch 86/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1908 - mse: 0.1908
# Epoch 87/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2024 - mse: 0.2024
# Epoch 88/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1969 - mse: 0.1969
# Epoch 89/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2068 - mse: 0.2068
# Epoch 90/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1973 - mse: 0.1973
# Epoch 91/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1864 - mse: 0.1864
# Epoch 92/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2049 - mse: 0.2049
# Epoch 93/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1966 - mse: 0.1966
# Epoch 94/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1993 - mse: 0.1993
# Epoch 95/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2028 - mse: 0.2028
# Epoch 96/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2037 - mse: 0.2037
# Epoch 97/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2045 - mse: 0.2045
# Epoch 98/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1989 - mse: 0.1989
# Epoch 99/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2033 - mse: 0.2033
# Epoch 100/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1954 - mse: 0.1954
# Epoch 101/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2038 - mse: 0.2038
# Epoch 102/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1967 - mse: 0.1967
# Epoch 103/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2010 - mse: 0.2010
# Epoch 104/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1964 - mse: 0.1964
# Epoch 105/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2048 - mse: 0.2048
# Epoch 106/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1944 - mse: 0.1944
# Epoch 107/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1958 - mse: 0.1958
# Epoch 108/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1997 - mse: 0.1997
# Epoch 109/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2005 - mse: 0.2005
# Epoch 110/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1979 - mse: 0.1979
# Epoch 111/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2015 - mse: 0.2015
# Epoch 112/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1942 - mse: 0.1942
# Epoch 113/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2047 - mse: 0.2047
# Epoch 114/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1938 - mse: 0.1938
# Epoch 115/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2000 - mse: 0.2000
# Epoch 116/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1979 - mse: 0.1979
# Epoch 117/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1949 - mse: 0.1949
# Epoch 118/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1966 - mse: 0.1966
# Epoch 119/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1938 - mse: 0.1938
# Epoch 120/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2019 - mse: 0.2019
# Epoch 121/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1944 - mse: 0.1944
# Epoch 122/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1960 - mse: 0.1960
# Epoch 123/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1999 - mse: 0.1999
# Epoch 124/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1953 - mse: 0.1953
# Epoch 125/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1957 - mse: 0.1957
# Epoch 126/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1971 - mse: 0.1971
# Epoch 127/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2024 - mse: 0.2024
# Epoch 128/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1900 - mse: 0.1900
# Epoch 129/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2038 - mse: 0.2038
# Epoch 130/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1892 - mse: 0.1892
# Epoch 131/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1967 - mse: 0.1967
# Epoch 132/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1914 - mse: 0.1914
# Epoch 133/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1934 - mse: 0.1934
# Epoch 134/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1961 - mse: 0.1961
# Epoch 135/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2020 - mse: 0.2020
# Epoch 136/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1949 - mse: 0.1949
# Epoch 137/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1920 - mse: 0.1920
# Epoch 138/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1906 - mse: 0.1906
# Epoch 139/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1974 - mse: 0.1974
# Epoch 140/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1978 - mse: 0.1978
# Epoch 141/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2007 - mse: 0.2007
# Epoch 142/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1917 - mse: 0.1917
# Epoch 143/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1990 - mse: 0.1990
# Epoch 144/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1988 - mse: 0.1988
# Epoch 145/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1909 - mse: 0.1909
# Epoch 146/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1886 - mse: 0.1886
# Epoch 147/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1978 - mse: 0.1978
# Epoch 148/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1919 - mse: 0.1919
# Epoch 149/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2010 - mse: 0.2010
# Epoch 150/150
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1995 - mse: 0.1995
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# - Find the RMSE on train data

# %%
# RMSE on train data (scaled)
np.sqrt(mean_squared_error(y_train_scaled, cv_baseline_preds))
# Out:
# 0.44182507823266515

# %% [markdown]
# - Convert the scaled predictions back to original scale
# - Calculate RMSE in the original units with `y_train` and `baseline_preds`

# %%
# Convert the predictions back to original scale
baseline_preds = ss_y.inverse_transform(cv_baseline_preds)

# RMSE on train data (original scale)
np.sqrt(mean_squared_error(y_train, baseline_preds))
# Out:
# 4024.3811768881937

# %% [markdown]
# ## Intentionally Overfitting a Model
#
# Now that you've developed a baseline model, its time to intentionally overfit a model. To overfit a model, you can:
# * Add layers
# * Make the layers bigger
# * Increase the number of training epochs
#
# Again, be careful here. Think about the limitations of your resources, both in terms of your computers specs and how much time and patience you have to let the process run. Also keep in mind that you will then be regularizing these overfit models, meaning another round of experiments and more time and resources.

# %%
# Define a function that returns a compiled Keras model 
def create_bigger_model():
    overfit = models.Sequential()
    overfit.add(layers.Input((n_features, )))
    overfit.add(layers.Dense(32, "relu"))
    overfit.add(layers.Dense(8, "relu"))
    overfit.add(layers.Dense(8, "relu"))
    overfit.add(layers.Dense(4, "relu"))
    overfit.add(layers.Dense(1, "linear"))
    
    overfit.compile(
        optimizer="sgd",
        loss="mse",
        metrics=["mse", "r2_score"]
    )
    
    return overfit

# %%
# Wrap the above function for use in cross-validation
keras_wrapper_2 = KerasRegressor(
    create_bigger_model,
    batch_size=256,
    epochs=500
)

# %%
# ⏰ This cell may take several mintes to run and you may get a comment from tf about optimizing your machine
# Generate cross-validated predictions
np.random.seed(123)
cv_bigger_model_preds = cross_val_predict(keras_wrapper_2, X_train_all, y_train_scaled)
# Out:
# Epoch 1/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.9097 - mse: 0.9097 - r2_score: 0.0735
# Epoch 2/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4087 - mse: 0.4087 - r2_score: 0.5756
# Epoch 3/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2726 - mse: 0.2726 - r2_score: 0.7213
# Epoch 4/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2490 - mse: 0.2490 - r2_score: 0.7524
# Epoch 5/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2353 - mse: 0.2353 - r2_score: 0.7620
# Epoch 6/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2302 - mse: 0.2302 - r2_score: 0.7667
# Epoch 7/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2207 - mse: 0.2207 - r2_score: 0.7786
# Epoch 8/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2187 - mse: 0.2187 - r2_score: 0.7733
# Epoch 9/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2176 - mse: 0.2176 - r2_score: 0.7832
# Epoch 10/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2164 - mse: 0.2164 - r2_score: 0.7771
# Epoch 11/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2122 - mse: 0.2122 - r2_score: 0.7884
# Epoch 12/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2108 - mse: 0.2108 - r2_score: 0.7880
# Epoch 13/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2090 - mse: 0.2090 - r2_score: 0.7820
# Epoch 14/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2120 - mse: 0.2120 - r2_score: 0.7806
# Epoch 15/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2088 - mse: 0.2088 - r2_score: 0.7853
# Epoch 16/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2082 - mse: 0.2082 - r2_score: 0.7884
# Epoch 17/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2038 - mse: 0.2038 - r2_score: 0.7942
# Epoch 18/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2016 - mse: 0.2016 - r2_score: 0.7962
# Epoch 19/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2042 - mse: 0.2042 - r2_score: 0.7914
# Epoch 20/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2068 - mse: 0.2068 - r2_score: 0.7900
# Epoch 21/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2069 - mse: 0.2069 - r2_score: 0.7898
# Epoch 22/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2058 - mse: 0.2058 - r2_score: 0.7934
# Epoch 23/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2032 - mse: 0.2032 - r2_score: 0.7941
# Epoch 24/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2068 - mse: 0.2068 - r2_score: 0.7869
# Epoch 25/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2022 - mse: 0.2022 - r2_score: 0.7952
# Epoch 26/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1972 - mse: 0.1972 - r2_score: 0.7985
# Epoch 27/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1830 - mse: 0.1830 - r2_score: 0.8166
# Epoch 347/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1830 - mse: 0.1830 - r2_score: 0.8159
# Epoch 348/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1863 - mse: 0.1863 - r2_score: 0.8094
# Epoch 349/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1800 - mse: 0.1800 - r2_score: 0.8173
# Epoch 350/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1949 - mse: 0.1949 - r2_score: 0.8015
# Epoch 351/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1778 - mse: 0.1778 - r2_score: 0.8162
# Epoch 352/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1731 - mse: 0.1731 - r2_score: 0.8229
# Epoch 353/500
# 94/94 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1857 - mse: 0.1857 - r2_score: 0.8106

# %%
# RMSE on train data (scaled)
np.sqrt(model.evaluate(X_test_all, y_test_scaled)[0])

# %% [markdown]
# ## Regularizing the Model to Achieve Balance
#
# Now that you have a powerful model (albeit an overfit one), we can now increase the generalization of the model by using some of the regularization techniques we discussed. Some options you have to try include:
# * Adding dropout
# * Adding L1/L2 regularization
# * Altering the layer architecture (add or remove layers similar to above)
#
# This process will be constrained by time and resources. Be sure to test at least two different methodologies, such as dropout and L2 regularization. If you have the time, feel free to continue experimenting.

# %%
# Define a function that returns a compiled Keras model 
def create_regularized_model():
    # Initialize model
    model = models.Sequential()

    # First hidden layer
    model.add(layers.Input((n_features,)))
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dropout(0.4))

    # Second hidden layer
    model.add(layers.Dense(8, activation='relu'))
    model.add(layers.Dropout(0.2))
    
    # Third hidden layer
    model.add(layers.Dense(8, activation='relu'))

    # Output layer
    model.add(layers.Dense(1, activation='linear'))

    # Compile the model
    model.compile(optimizer='SGD',
                  loss='mse',
                  metrics=['mse'])
    
    return model

# %%
# Wrap the above function for use in cross-validation
keras_wrapper_3 = KerasRegressor(
    create_regularized_model,
    batch_size=256,
    epochs=150
)

# %%
# ⏰ This cell may take several minutes to run, and you may get a comment from tf about optimizing your machine
# Generate cross-validated predictions
np.random.seed(123)
cv_dropout_preds = cross_val_predict(keras_wrapper_3, X_train_all, y_train_scaled)

# %%
# RMSE on train data (scaled)
np.sqrt(mean_squared_error(y_train_scaled, cv_dropout_preds))

# %% [markdown]
# ## Final Evaluation
#
# Now that you have selected a network architecture, tested various regularization procedures and tuned hyperparameters via a validation methodology, it is time to evaluate your final model on the test set. Fit the model using all of the training data using the architecture and hyperparameters that were most effective in your experiments above. Afterwards, measure the overall performance on the hold-out test data which has been left untouched (and hasn't leaked any data into the modeling process)!

# %%
# ⏰ This cell may take several mintes to run and you may get a comment from tf about optimizing your machine

# %%
# Initialize model
model = models.Sequential()

# First hidden layer
model.add(layers.Input((n_features,)))
model.add(layers.Dense(10, activation='relu'))

# Second hidden layer
model.add(layers.Dense(5, activation='relu'))

# Output layer
model.add(layers.Dense(1, activation='linear'))

# Compile the model
model.compile(optimizer='SGD',
              loss='mse',
              metrics=['mse'])

# %%
model.fit(X_train_all, y_train_scaled, batch_size=256, epochs=150)

# %%
np.sqrt(model.evaluate(X_test_all, y_test_scaled)[0])

# %% [markdown]
# ## Summary
#
# In this lab, you investigated some data from *The Lending Club* in a complete data science pipeline to build neural networks with good performance. You began with reserving a hold-out set for testing which never was touched during the modeling phase. From there, you implemented a k-fold cross validation methodology in order to assess an initial baseline model and various regularization methods.
